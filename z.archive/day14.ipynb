# %% [markdown]
# Day14 Higher lower

# %%
#Day14 Higher from game_data import data
from game_data import data
from art import logo, vs 
import random
import os

# Clear the screen
os.system('cls' if os.name == 'nt' else 'clear')
print(logo)


keep_playing = False
#Ask the player if they want to play a game.
# response = input("Do you want to play a game y/n")
# if response == "y":
#   keep_playing = True
  
def higher_lower():
    keep_playing = True
    first_contender = random.choice(data)
    next_contender = random.choice(data)      
    correct_choice = ""
    score = 0
    while keep_playing == True:
        print("I'm going to print you two entities, tell me if the second is higher or lower than the first:")
        print("\n*******************************")
        print(f"\n{first_contender['name']}")        
        print(f"\n{vs}")
        print(f"\n{next_contender['name']}")
        print("\n*******************************")
        print(f"Your score: {score}")
        choice = input("Will the second contender be higher or lower?: \n h/l?:")
        if choice == "h":
            higher = True
        else:
            higher = False        
        #how to get the correct choice into the variable
        if first_contender['follower_count'] > next_contender['follower_count']:
            print(f"{first_contender['name']} is higher than {next_contender['name']}")
            if not higher:
                print("you win")
                score += 1
                print(f"Your score is: {score}")
                keep_playing = True
                next_contender = random.choice(data)    
                os.system 
            else:
                print("you lose")
                print(f"Final score: {score}")
                break
        else: 
            print(f"{next_contender['name']} is higher than {first_contender['name']}")
            first_contender = next_contender
            next_contender = random.choice(data)     
            if higher:
                print("you win")
                score += 1
                print(f"Your score is: {score}")
                keep_playing = True
                os.system
                
            else:
                print("you lose")
                print(f"Final score: {score}")
                break
higher_lower()
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# I'm going to print you two entities, tell me if the second is higher or lower than the first:
#
# *******************************
#
# Ellen DeGeneres
#
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
#
# Justin Timberlake
#
# *******************************
# Your score: 0
# Ellen DeGeneres is higher than Justin Timberlake
# you lose
# Final score: 0
